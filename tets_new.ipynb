# %% [markdown]
# ## **Tải dữ liệu**

# %%
# !gdown 1ezkXHiA8upwUlEM6EiQGj4VQJEvsUNLI
# !unzip /content/ASL_alphabet.zip -d /content/dataset

# %% [markdown]
# ## **Nhập các thư viện cần thiết**

# %%
import cv2
from glob import glob
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import plotly
from plotly.subplots import make_subplots
import plotly.graph_objects as go

import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print(tf.__version__)
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Loading inception v3 network for transfer learning
from tensorflow.keras import layers, Model
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.optimizers import Adam, SGD

from sklearn.model_selection import train_test_split

# %% [markdown]
# # **2. Chuẩn bị và tiền xử lý dữ liệu**

# %% [markdown]
# ## **Config**

# %%
TRAINING_DIR = './dataset/train'
TEST_DIR = './dataset/test/'
CLASSES = [folder[len(TRAINING_DIR)+1:] for folder in glob(TRAINING_DIR + '/*')]
CLASSES.sort()

IMAGE_SIZE = 200
BATCH_SIZE = 64
N_CLASSES = 29
TRAIN_SIZE = 0.8
VALIDATION_SIZE = 0.1
TEST_SIZE = 0.1
MODEL_PATH = './models/cnn_asl_model.h5'

# %% [markdown]
# ## **Data visualize**

# %%
# %matplotlib inline

def plot_one_sample_of_each(base_path):
    cols = 5
    rows = int(np.ceil(len(CLASSES) / cols))
    fig = plt.figure(figsize=(16, 20))

    for i in range(len(CLASSES)):
        cls = CLASSES[i]
        img_path = base_path + '/' + cls + '/**'
        path_contents = glob(img_path)

        imgs = random.sample(path_contents, 1)

        sp = plt.subplot(rows, cols, i + 1)
        plt.imshow(cv2.imread(imgs[0]))
        plt.title(cls)
        sp.axis('off')

    plt.show()

plot_one_sample_of_each(TRAINING_DIR)

# %% [markdown]
# ## **Tiền xử lý dữ liệu**

# %%
list_path = []
list_labels = []

# Assuming CLASSES contains the names of subdirectories (classes) in TRAINING_DIR
for label in CLASSES:
    # Create a path pattern for each label folder and image file types
    label_path = os.path.join(TRAINING_DIR, label, "*")
    image_files = glob(label_path)
    
    # Filter out non-image files (optional)
    image_files = [f for f in image_files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    # Create a label list for the current label
    sign_label = [label] * len(image_files)

    # Extend the list with current label's image paths and labels
    list_path.extend(image_files)
    list_labels.extend(sign_label)

# Create a DataFrame to store the image paths and labels
metadata = pd.DataFrame({
    "image_path": list_path,
    "label": list_labels
})

metadata

# %%
# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    metadata["image_path"], metadata["label"],
    test_size=TEST_SIZE,
    random_state=2023,
    shuffle=True,
    stratify=metadata["label"]
)

# Create a DataFrame for the training data
data_train = pd.DataFrame({
    "image_path": X_train,
    "label": y_train
})

# Calculate validation size relative to training size
validation_size = VALIDATION_SIZE / TRAIN_SIZE

# Split the training data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    data_train["image_path"], data_train["label"],
    test_size=validation_size,
    random_state=2023,
    shuffle=True,
    stratify=data_train["label"]
)

# Create DataFrames for train, validation, and test data
data_train = pd.DataFrame({
    "image_path": X_train,
    "label": y_train
})

data_val = pd.DataFrame({
    "image_path": X_val,
    "label": y_val
})

data_test = pd.DataFrame({
    "image_path": X_test,
    "label": y_test
})

# Optional: Check the first few rows of each dataframe to verify
print("Training Data:")
print(data_train.head())
print("Validation Data:")
print(data_val.head())
print("Test Data:")
print(data_test.head())

# %%
datagen = ImageDataGenerator(rescale=1/255.,)

train_gen = ImageDataGenerator(
    rescale=1/255.,
    brightness_range=[0.8,1.2],
    zoom_range=[1.0,1.2],
    horizontal_flip=True)

train_generator = train_gen.flow_from_dataframe(
        data_train,
        directory="./",
        x_col="image_path",
        y_col="label",
        class_mode="categorical",
        batch_size=BATCH_SIZE,
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
    )

validation_generator = datagen.flow_from_dataframe(
        data_val,
        directory="./",
        x_col="image_path",
        y_col="label",
        class_mode="categorical",
        batch_size=BATCH_SIZE,
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
    )

test_generator = datagen.flow_from_dataframe(
        data_val,
        directory="./",
        x_col="image_path",
        y_col="label",
        class_mode="categorical",
        batch_size=1,
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        shuffle=False
)

# %% [markdown]
# # **3. Xây dựng mô hình**

# %% [markdown]
# ## **Transfer learning using Inception V3 Network**

# %%
from tensorflow.keras.models import load_model
MODEL_PATH1 = './models/fine_tune_asl_model.h5'
if os.path.exists(MODEL_PATH1):
    # Nếu mô hình đã có sẵn, tải lại mô hình
    model = load_model(MODEL_PATH1)
    print("Loaded saved model from disk.")
else:    
    base_model = InceptionV3(
        input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3),
        include_top = False,
        weights = 'imagenet'
    )

    for layer in base_model.layers:
            layer.trainable = False
    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(1024, activation='relu')(x)
    predictions = layers.Dense(36, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Loaded saved model from disk.

# %% [markdown]
# ## **Huấn luyện mô hình**

# %% [markdown]
# **Looking at the final model:**

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 200, 200, 3  0           []
#                                 )]
#
#  conv2d_94 (Conv2D)             (None, 99, 99, 32)   864         ['input_2[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 99, 99, 32)  96          ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_94 (Activation)     (None, 99, 99, 32)   0           ['batch_normalization_94[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 97, 97, 32)   9216        ['activation_94[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 97, 97, 32)  96          ['conv2d_95[0][0]']
#  ormalization)
#
#  activation_95 (Activation)     (None, 97, 97, 32)   0           ['batch_normalization_95[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 97, 97, 64)   18432       ['activation_95[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 97, 97, 64)  192         ['conv2d_96[0][0]']
#  ormalization)
#
#  activation_96 (Activation)     (None, 97, 97, 64)   0           ['batch_normalization_96[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 48, 48, 64)  0           ['activation_96[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 48, 48, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 48, 48, 80)  240         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_97 (Activation)     (None, 48, 48, 80)   0           ['batch_normalization_97[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 46, 46, 192)  138240      ['activation_97[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 46, 46, 192)  576        ['conv2d_98[0][0]']
#  ormalization)
#
#  activation_98 (Activation)     (None, 46, 46, 192)  0           ['batch_normalization_98[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 22, 22, 192)  0          ['activation_98[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 22, 22, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_102 (Batch  (None, 22, 22, 64)  192         ['conv2d_102[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_102[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 22, 22, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 22, 22, 96)   55296       ['activation_102[0][0]']
#
#  batch_normalization_100 (Batch  (None, 22, 22, 48)  144         ['conv2d_100[0][0]']
#  Normalization)
#
#  batch_normalization_103 (Batch  (None, 22, 22, 96)  288         ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 22, 22, 48)   0           ['batch_normalization_100[0][0]']
#
#  activation_103 (Activation)    (None, 22, 22, 96)   0           ['batch_normalization_103[0][0]']
#
#  average_pooling2d_9 (AveragePo  (None, 22, 22, 192)  0          ['max_pooling2d_5[0][0]']
#  oling2D)
#
#  conv2d_99 (Conv2D)             (None, 22, 22, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 22, 22, 64)   76800       ['activation_100[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 22, 22, 96)   82944       ['activation_103[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 22, 22, 32)   6144        ['average_pooling2d_9[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 22, 22, 64)  192         ['conv2d_99[0][0]']
#  ormalization)
#
#  batch_normalization_101 (Batch  (None, 22, 22, 64)  192         ['conv2d_101[0][0]']
#  Normalization)
#
#  batch_normalization_104 (Batch  (None, 22, 22, 96)  288         ['conv2d_104[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (None, 22, 22, 32)  96          ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_99 (Activation)     (None, 22, 22, 64)   0           ['batch_normalization_99[0][0]']
#
#  activation_101 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_101[0][0]']
#
#  activation_104 (Activation)    (None, 22, 22, 96)   0           ['batch_normalization_104[0][0]']
#
#  activation_105 (Activation)    (None, 22, 22, 32)   0           ['batch_normalization_105[0][0]']
#
#  mixed0 (Concatenate)           (None, 22, 22, 256)  0           ['activation_99[0][0]',
#                                                                   'activation_101[0][0]',
#                                                                   'activation_104[0][0]',
#                                                                   'activation_105[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 22, 22, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_109 (Batch  (None, 22, 22, 64)  192         ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_109[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 22, 22, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 22, 22, 96)   55296       ['activation_109[0][0]']
#
#  batch_normalization_107 (Batch  (None, 22, 22, 48)  144         ['conv2d_107[0][0]']
#  Normalization)
#
#  batch_normalization_110 (Batch  (None, 22, 22, 96)  288         ['conv2d_110[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 22, 22, 48)   0           ['batch_normalization_107[0][0]']
#
#  activation_110 (Activation)    (None, 22, 22, 96)   0           ['batch_normalization_110[0][0]']
#
#  average_pooling2d_10 (AverageP  (None, 22, 22, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_106 (Conv2D)            (None, 22, 22, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 22, 22, 64)   76800       ['activation_107[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 22, 22, 96)   82944       ['activation_110[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 22, 22, 64)   16384       ['average_pooling2d_10[0][0]']
#
#  batch_normalization_106 (Batch  (None, 22, 22, 64)  192         ['conv2d_106[0][0]']
#  Normalization)
#
#  batch_normalization_108 (Batch  (None, 22, 22, 64)  192         ['conv2d_108[0][0]']
#  Normalization)
#
#  batch_normalization_111 (Batch  (None, 22, 22, 96)  288         ['conv2d_111[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (None, 22, 22, 64)  192         ['conv2d_112[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_106[0][0]']
#
#  activation_108 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_108[0][0]']
#
#  activation_111 (Activation)    (None, 22, 22, 96)   0           ['batch_normalization_111[0][0]']
#
#  activation_112 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_112[0][0]']
#
#  mixed1 (Concatenate)           (None, 22, 22, 288)  0           ['activation_106[0][0]',
#                                                                   'activation_108[0][0]',
#                                                                   'activation_111[0][0]',
#                                                                   'activation_112[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 22, 22, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_116 (Batch  (None, 22, 22, 64)  192         ['conv2d_116[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_116[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 22, 22, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 22, 22, 96)   55296       ['activation_116[0][0]']
#
#  batch_normalization_114 (Batch  (None, 22, 22, 48)  144         ['conv2d_114[0][0]']
#  Normalization)
#
#  batch_normalization_117 (Batch  (None, 22, 22, 96)  288         ['conv2d_117[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 22, 22, 48)   0           ['batch_normalization_114[0][0]']
#
#  activation_117 (Activation)    (None, 22, 22, 96)   0           ['batch_normalization_117[0][0]']
#
#  average_pooling2d_11 (AverageP  (None, 22, 22, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_113 (Conv2D)            (None, 22, 22, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 22, 22, 64)   76800       ['activation_114[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 22, 22, 96)   82944       ['activation_117[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 22, 22, 64)   18432       ['average_pooling2d_11[0][0]']
#
#  batch_normalization_113 (Batch  (None, 22, 22, 64)  192         ['conv2d_113[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (None, 22, 22, 64)  192         ['conv2d_115[0][0]']
#  Normalization)
#
#  batch_normalization_118 (Batch  (None, 22, 22, 96)  288         ['conv2d_118[0][0]']
#  Normalization)
#
#  batch_normalization_119 (Batch  (None, 22, 22, 64)  192         ['conv2d_119[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_113[0][0]']
#
#  activation_115 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_115[0][0]']
#
#  activation_118 (Activation)    (None, 22, 22, 96)   0           ['batch_normalization_118[0][0]']
#
#  activation_119 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_119[0][0]']
#
#  mixed2 (Concatenate)           (None, 22, 22, 288)  0           ['activation_113[0][0]',
#                                                                   'activation_115[0][0]',
#                                                                   'activation_118[0][0]',
#                                                                   'activation_119[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 22, 22, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_121 (Batch  (None, 22, 22, 64)  192         ['conv2d_121[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_121[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 22, 22, 96)   55296       ['activation_121[0][0]']
#
#  batch_normalization_122 (Batch  (None, 22, 22, 96)  288         ['conv2d_122[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 22, 22, 96)   0           ['batch_normalization_122[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 10, 10, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 10, 10, 96)   82944       ['activation_122[0][0]']
#
#  batch_normalization_120 (Batch  (None, 10, 10, 384)  1152       ['conv2d_120[0][0]']
#  Normalization)
#
#  batch_normalization_123 (Batch  (None, 10, 10, 96)  288         ['conv2d_123[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 10, 10, 384)  0           ['batch_normalization_120[0][0]']
#
#  activation_123 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_123[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 10, 10, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 10, 10, 768)  0           ['activation_120[0][0]',
#                                                                   'activation_123[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 10, 10, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_128 (Batch  (None, 10, 10, 128)  384        ['conv2d_128[0][0]']
#  Normalization)
#
#  activation_128 (Activation)    (None, 10, 10, 128)  0           ['batch_normalization_128[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 10, 10, 128)  114688      ['activation_128[0][0]']
#
#  batch_normalization_129 (Batch  (None, 10, 10, 128)  384        ['conv2d_129[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 10, 10, 128)  0           ['batch_normalization_129[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 10, 10, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 10, 10, 128)  114688      ['activation_129[0][0]']
#
#  batch_normalization_125 (Batch  (None, 10, 10, 128)  384        ['conv2d_125[0][0]']
#  Normalization)
#
#  batch_normalization_130 (Batch  (None, 10, 10, 128)  384        ['conv2d_130[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 10, 10, 128)  0           ['batch_normalization_125[0][0]']
#
#  activation_130 (Activation)    (None, 10, 10, 128)  0           ['batch_normalization_130[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 10, 10, 128)  114688      ['activation_125[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 10, 10, 128)  114688      ['activation_130[0][0]']
#
#  batch_normalization_126 (Batch  (None, 10, 10, 128)  384        ['conv2d_126[0][0]']
#  Normalization)
#
#  batch_normalization_131 (Batch  (None, 10, 10, 128)  384        ['conv2d_131[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 10, 10, 128)  0           ['batch_normalization_126[0][0]']
#
#  activation_131 (Activation)    (None, 10, 10, 128)  0           ['batch_normalization_131[0][0]']
#
#  average_pooling2d_12 (AverageP  (None, 10, 10, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_124 (Conv2D)            (None, 10, 10, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 10, 10, 192)  172032      ['activation_126[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 10, 10, 192)  172032      ['activation_131[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 10, 10, 192)  147456      ['average_pooling2d_12[0][0]']
#
#  batch_normalization_124 (Batch  (None, 10, 10, 192)  576        ['conv2d_124[0][0]']
#  Normalization)
#
#  batch_normalization_127 (Batch  (None, 10, 10, 192)  576        ['conv2d_127[0][0]']
#  Normalization)
#
#  batch_normalization_132 (Batch  (None, 10, 10, 192)  576        ['conv2d_132[0][0]']
#  Normalization)
#
#  batch_normalization_133 (Batch  (None, 10, 10, 192)  576        ['conv2d_133[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_124[0][0]']
#
#  activation_127 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_127[0][0]']
#
#  activation_132 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_132[0][0]']
#
#  activation_133 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_133[0][0]']
#
#  mixed4 (Concatenate)           (None, 10, 10, 768)  0           ['activation_124[0][0]',
#                                                                   'activation_127[0][0]',
#                                                                   'activation_132[0][0]',
#                                                                   'activation_133[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 10, 10, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_138 (Batch  (None, 10, 10, 160)  480        ['conv2d_138[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_138[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_138[0][0]']
#
#  batch_normalization_139 (Batch  (None, 10, 10, 160)  480        ['conv2d_139[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_139[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 10, 10, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_139[0][0]']
#
#  batch_normalization_135 (Batch  (None, 10, 10, 160)  480        ['conv2d_135[0][0]']
#  Normalization)
#
#  batch_normalization_140 (Batch  (None, 10, 10, 160)  480        ['conv2d_140[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_135[0][0]']
#
#  activation_140 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_140[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_135[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_140[0][0]']
#
#  batch_normalization_136 (Batch  (None, 10, 10, 160)  480        ['conv2d_136[0][0]']
#  Normalization)
#
#  batch_normalization_141 (Batch  (None, 10, 10, 160)  480        ['conv2d_141[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_136[0][0]']
#
#  activation_141 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_141[0][0]']
#
#  average_pooling2d_13 (AverageP  (None, 10, 10, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_134 (Conv2D)            (None, 10, 10, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 10, 10, 192)  215040      ['activation_136[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 10, 10, 192)  215040      ['activation_141[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 10, 10, 192)  147456      ['average_pooling2d_13[0][0]']
#
#  batch_normalization_134 (Batch  (None, 10, 10, 192)  576        ['conv2d_134[0][0]']
#  Normalization)
#
#  batch_normalization_137 (Batch  (None, 10, 10, 192)  576        ['conv2d_137[0][0]']
#  Normalization)
#
#  batch_normalization_142 (Batch  (None, 10, 10, 192)  576        ['conv2d_142[0][0]']
#  Normalization)
#
#  batch_normalization_143 (Batch  (None, 10, 10, 192)  576        ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_134[0][0]']
#
#  activation_137 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_137[0][0]']
#
#  activation_142 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_142[0][0]']
#
#  activation_143 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_143[0][0]']
#
#  mixed5 (Concatenate)           (None, 10, 10, 768)  0           ['activation_134[0][0]',
#                                                                   'activation_137[0][0]',
#                                                                   'activation_142[0][0]',
#                                                                   'activation_143[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 10, 10, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_148 (Batch  (None, 10, 10, 160)  480        ['conv2d_148[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_148[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_148[0][0]']
#
#  batch_normalization_149 (Batch  (None, 10, 10, 160)  480        ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_149[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 10, 10, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_149[0][0]']
#
#  batch_normalization_145 (Batch  (None, 10, 10, 160)  480        ['conv2d_145[0][0]']
#  Normalization)
#
#  batch_normalization_150 (Batch  (None, 10, 10, 160)  480        ['conv2d_150[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_145[0][0]']
#
#  activation_150 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_150[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_145[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 10, 10, 160)  179200      ['activation_150[0][0]']
#
#  batch_normalization_146 (Batch  (None, 10, 10, 160)  480        ['conv2d_146[0][0]']
#  Normalization)
#
#  batch_normalization_151 (Batch  (None, 10, 10, 160)  480        ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_146[0][0]']
#
#  activation_151 (Activation)    (None, 10, 10, 160)  0           ['batch_normalization_151[0][0]']
#
#  average_pooling2d_14 (AverageP  (None, 10, 10, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_144 (Conv2D)            (None, 10, 10, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 10, 10, 192)  215040      ['activation_146[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 10, 10, 192)  215040      ['activation_151[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 10, 10, 192)  147456      ['average_pooling2d_14[0][0]']
#
#  batch_normalization_144 (Batch  (None, 10, 10, 192)  576        ['conv2d_144[0][0]']
#  Normalization)
#
#  batch_normalization_147 (Batch  (None, 10, 10, 192)  576        ['conv2d_147[0][0]']
#  Normalization)
#
#  batch_normalization_152 (Batch  (None, 10, 10, 192)  576        ['conv2d_152[0][0]']
#  Normalization)
#
#  batch_normalization_153 (Batch  (None, 10, 10, 192)  576        ['conv2d_153[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_144[0][0]']
#
#  activation_147 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_147[0][0]']
#
#  activation_152 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_152[0][0]']
#
#  activation_153 (Activation)    (None, 10, 10, 192)  0           ['batch_normalization_153[0][0]']
#
#  mixed6 (Concatenate)           (None, 10, 10, 768)  0           ['activation_144[0][0]',
#                                                                   'activation_147[0][0]',
#                                                                   'activation_152[0][0]',
#                                                                   'activation_153[0][0]']
#
# ...
#
#  activation_174 (Activation)    (None, 4, 4, 448)    0           ['batch_normalization_174[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 4, 4, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 4, 4, 384)    1548288     ['activation_174[0][0]']
#
#  batch_normalization_171 (Batch  (None, 4, 4, 384)   1152        ['conv2d_171[0][0]']
#  Normalization)
#
#  batch_normalization_175 (Batch  (None, 4, 4, 384)   1152        ['conv2d_175[0][0]']
#  Normalization)
#
#  activation_171 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_171[0][0]']
#
#  activation_175 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_175[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_171[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_171[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_175[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_175[0][0]']
#
#  average_pooling2d_16 (AverageP  (None, 4, 4, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_170 (Conv2D)            (None, 4, 4, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_172 (Batch  (None, 4, 4, 384)   1152        ['conv2d_172[0][0]']
#  Normalization)
#
#  batch_normalization_173 (Batch  (None, 4, 4, 384)   1152        ['conv2d_173[0][0]']
#  Normalization)
#
#  batch_normalization_176 (Batch  (None, 4, 4, 384)   1152        ['conv2d_176[0][0]']
#  Normalization)
#
#  batch_normalization_177 (Batch  (None, 4, 4, 384)   1152        ['conv2d_177[0][0]']
#  Normalization)
#
#  conv2d_178 (Conv2D)            (None, 4, 4, 192)    245760      ['average_pooling2d_16[0][0]']
#
#  batch_normalization_170 (Batch  (None, 4, 4, 320)   960         ['conv2d_170[0][0]']
#  Normalization)
#
#  activation_172 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_172[0][0]']
#
#  activation_173 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_173[0][0]']
#
#  activation_176 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_176[0][0]']
#
#  activation_177 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_177[0][0]']
#
#  batch_normalization_178 (Batch  (None, 4, 4, 192)   576         ['conv2d_178[0][0]']
#  Normalization)
#
#  activation_170 (Activation)    (None, 4, 4, 320)    0           ['batch_normalization_170[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 4, 4, 768)    0           ['activation_172[0][0]',
#                                                                   'activation_173[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 4, 4, 768)    0           ['activation_176[0][0]',
#                                                                   'activation_177[0][0]']
#
#  activation_178 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_178[0][0]']
#
#  mixed9 (Concatenate)           (None, 4, 4, 2048)   0           ['activation_170[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'activation_178[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 4, 4, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_183 (Batch  (None, 4, 4, 448)   1344        ['conv2d_183[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (None, 4, 4, 448)    0           ['batch_normalization_183[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 4, 4, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 4, 4, 384)    1548288     ['activation_183[0][0]']
#
#  batch_normalization_180 (Batch  (None, 4, 4, 384)   1152        ['conv2d_180[0][0]']
#  Normalization)
#
#  batch_normalization_184 (Batch  (None, 4, 4, 384)   1152        ['conv2d_184[0][0]']
#  Normalization)
#
#  activation_180 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_180[0][0]']
#
#  activation_184 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_184[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_180[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_180[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_184[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_184[0][0]']
#
#  average_pooling2d_17 (AverageP  (None, 4, 4, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_179 (Conv2D)            (None, 4, 4, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_181 (Batch  (None, 4, 4, 384)   1152        ['conv2d_181[0][0]']
#  Normalization)
#
#  batch_normalization_182 (Batch  (None, 4, 4, 384)   1152        ['conv2d_182[0][0]']
#  Normalization)
#
#  batch_normalization_185 (Batch  (None, 4, 4, 384)   1152        ['conv2d_185[0][0]']
#  Normalization)
#
#  batch_normalization_186 (Batch  (None, 4, 4, 384)   1152        ['conv2d_186[0][0]']
#  Normalization)
#
#  conv2d_187 (Conv2D)            (None, 4, 4, 192)    393216      ['average_pooling2d_17[0][0]']
#
#  batch_normalization_179 (Batch  (None, 4, 4, 320)   960         ['conv2d_179[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_181[0][0]']
#
#  activation_182 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_182[0][0]']
#
#  activation_185 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_185[0][0]']
#
#  activation_186 (Activation)    (None, 4, 4, 384)    0           ['batch_normalization_186[0][0]']
#
#  batch_normalization_187 (Batch  (None, 4, 4, 192)   576         ['conv2d_187[0][0]']
#  Normalization)
#
#  activation_179 (Activation)    (None, 4, 4, 320)    0           ['batch_normalization_179[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 4, 4, 768)    0           ['activation_181[0][0]',
#                                                                   'activation_182[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 4, 4, 768)    0           ['activation_185[0][0]',
#                                                                   'activation_186[0][0]']
#
#  activation_187 (Activation)    (None, 4, 4, 192)    0           ['batch_normalization_187[0][0]']
#
#  mixed10 (Concatenate)          (None, 4, 4, 2048)   0           ['activation_179[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'activation_187[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['mixed10[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 1024)         2098176     ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_3 (Dense)                (None, 36)           36900       ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 23,937,860
# Trainable params: 13,249,956
# Non-trainable params: 10,687,904
# __________________________________________________________________________________________________

# %% [markdown]
# **Setting up a callback funtion in order to stop training at a particular threshold:**

# %% [markdown]
# **Fit model :**

# %%
import scipy

# or import specific modules
from scipy import stats, linalg

# %%
train_history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=5,
)

# %% [markdown]
# ## **Fine-Tuning**

# %%
for layer in model.layers[:249]:
   layer.trainable = False
for layer in model.layers[249:]:
   layer.trainable = True

model.compile(optimizer=SGD(learning_rate=0.0001, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 200, 200, 3  0           []
#                                 )]
#
#  conv2d_94 (Conv2D)             (None, 99, 99, 32)   864         ['input_2[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 99, 99, 32)  96          ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_94 (Activation)     (None, 99, 99, 32)   0           ['batch_normalization_94[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 97, 97, 32)   9216        ['activation_94[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 97, 97, 32)  96          ['conv2d_95[0][0]']
#  ormalization)
#
#  activation_95 (Activation)     (None, 97, 97, 32)   0           ['batch_normalization_95[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 97, 97, 64)   18432       ['activation_95[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 97, 97, 64)  192         ['conv2d_96[0][0]']
#  ormalization)
#
#  activation_96 (Activation)     (None, 97, 97, 64)   0           ['batch_normalization_96[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 48, 48, 64)  0           ['activation_96[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 48, 48, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 48, 48, 80)  240         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_97 (Activation)     (None, 48, 48, 80)   0           ['batch_normalization_97[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 46, 46, 192)  138240      ['activation_97[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 46, 46, 192)  576        ['conv2d_98[0][0]']
#  ormalization)
#
#  activation_98 (Activation)     (None, 46, 46, 192)  0           ['batch_normalization_98[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 22, 22, 192)  0          ['activation_98[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 22, 22, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_102 (Batch  (None, 22, 22, 64)  192         ['conv2d_102[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 22, 22, 64)   0           ['batch_normalization_102[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 22, 22, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 22, 22, 96)   55296       ['activation_102[0][0]']
#
#  batch_normalization_100 (Batch  (None, 22, 22, 48)  144         ['conv2d_100[0][0]']
#  Normalization)
#
#  batch_normalization_103 (Batch  (None, 22, 22, 96)  288         ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 22, 22, 48)   0           ['batch_normalization_100[0][0]']
#
#  activation_103 (Activation)    (None, 22, 22, 96)   0           ['batch_normalization_103[0][0]']
#
#  average_pooling2d_9 (AveragePo  (None, 22, 22, 192)  0          ['max_pooling2d_5[0][0]']
#  oling2D)
#
#  conv2d_99 (Conv2D)             (None, 22, 22, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 22, 22, 64)   76800       ['activation_100[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 22, 22, 96)   82944       ['activation_103[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 22, 22, 32)   6144        ['average_pooling2d_9[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 22, 22, 64)  192         ['conv2d_99[0][0]']
#  ormalization)
#
#  batch_normalization_101 (Batch  (None,
50
# 31/31 [==============================] - 15s 471ms/step - loss: 0.0593 - accuracy: 0.9960 - val_loss: 0.1505 - val_accuracy: 0.9682
# Epoch 35/50
# 31/31 [==============================] - 15s 471ms/step - loss: 0.0617 - accuracy: 0.9955 - val_loss: 0.1505 - val_accuracy: 0.9682
# Epoch 36/50
# 31/31 [==============================] - 15s 464ms/step - loss: 0.0594 - accuracy: 0.9980 - val_loss: 0.1494 - val_accuracy: 0.9682
# Epoch 37/50
# 31/31 [==============================] - 15s 490ms/step - loss: 0.0577 - accuracy: 0.9990 - val_loss: 0.1482 - val_accuracy: 0.9682
# Epoch 38/50
# 31/31 [==============================] - 15s 486ms/step - loss: 0.0561 - accuracy: 0.9975 - val_loss: 0.1466 - val_accuracy: 0.9682
# Epoch 39/50
# 31/31 [==============================] - 15s 470ms/step - loss: 0.0558 - accuracy: 0.9975 - val_loss: 0.1463 - val_accuracy: 0.9682
# Epoch 40/50
# 31/31 [==============================] - 15s 470ms/step - loss: 0.0577 - accuracy: 0.9965 - val_loss: 0.1461 - val_accuracy: 0.9682
# Epoch 41/50
# 31/31 [==============================] - 16s 506ms/step - loss: 0.0534 - accuracy: 0.9980 - val_loss: 0.1453 - val_accuracy: 0.9717
# Epoch 42/50
# 31/31 [==============================] - 15s 480ms/step - loss: 0.0567 - accuracy: 0.9990 - val_loss: 0.1445 - val_accuracy: 0.9682
# Epoch 43/50
# 31/31 [==============================] - 15s 478ms/step - loss: 0.0543 - accuracy: 0.9960 - val_loss: 0.1437 - val_accuracy: 0.9717
# Epoch 44/50
# 31/31 [==============================] - 15s 474ms/step - loss: 0.0508 - accuracy: 0.9975 - val_loss: 0.1427 - val_accuracy: 0.9682
# Epoch 45/50
# 31/31 [==============================] - 15s 469ms/step - loss: 0.0535 - accuracy: 0.9985 - val_loss: 0.1416 - val_accuracy: 0.9682
# Epoch 46/50
# 31/31 [==============================] - 15s 463ms/step - loss: 0.0488 - accuracy: 0.9990 - val_loss: 0.1414 - val_accuracy: 0.9682
# Epoch 47/50
# 31/31 [==============================] - 15s 469ms/step - loss: 0.0546 - accuracy: 0.9985 - val_loss: 0.1413 - val_accuracy: 0.9717
# Epoch 48/50
# 31/31 [==============================] - 15s 464ms/step - loss: 0.0528 - accuracy: 0.9985 - val_loss: 0.1408 - val_accuracy: 0.9717
# Epoch 49/50
# 31/31 [==============================] - 15s 467ms/step - loss: 0.0537 - accuracy: 0.9985 - val_loss: 0.1399 - val_accuracy: 0.9717
# Epoch 50/50
# 31/31 [==============================] - 15s 467ms/step - loss: 0.0509 - accuracy: 0.9970 - val_loss: 0.1387 - val_accuracy: 0.9717

# %% [markdown]
# ## **Lưu mô hình**

# %% [markdown]
# **As we were satisfied with our results we save our model:**

# %%
model.endswith(fine_tune_history)

# %%
MODEL_PATH1 = './models/fine_tune_asl_model.h5'
model.save(MODEL_PATH1)

# %%
# Saving the model
model.save(MODEL_PATH)

# %% [markdown]
# # **4. Đánh giá mô hình**

# %% [markdown]
# ## **Model Testing**

# %%
from sklearn.metrics import accuracy_score

# %%
predictions = model.predict(test_generator)
predictions = predictions.argmax(axis=1)
true_labels = test_generator.classes

accuracy = accuracy_score(predictions, true_labels)
print("%s: %.2f%%" % ("Evaluate Test Accuracy", accuracy))

# %% [markdown]
# ## **Training Loss and Metrics**

# %%
def visualize_train_val(history):
  # Visualize Training and Validation Results
  fig = make_subplots(
          rows=1, cols=2,
          subplot_titles=["Model Loss", "Model Accuracy"],
  )

  # Configuration Plot
  class PlotCFG:
      marker_size = 8
      line_size = 2
      train_color = "#76503d"
      valid_color = "#deb392"


  # Loss Plot
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  fig.add_trace(
      go.Scatter(
          x=np.arange(1, len(loss)+1), y=loss,
          mode="markers+lines",
          marker=dict(
              color=PlotCFG.train_color, size=PlotCFG.marker_size,
              line=dict(color="White", width=0.5)
          ),
          line=dict(color=PlotCFG.train_color, width=PlotCFG.line_size),
          name="Training Loss"
      ), row=1, col=1
  )

  fig.add_trace(
      go.Scatter(
          x=np.arange(1, len(val_loss)+1), y=val_loss,
          mode="markers+lines",
          marker=dict(
              color=PlotCFG.valid_color, size=PlotCFG.marker_size,
              line=dict(color="White", width=0.5)
          ),
          line=dict(color=PlotCFG.valid_color, width=PlotCFG.line_size),
          name="Validation Loss"
      ), row=1, col=1
  )



  # Accuracy Plot
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  fig.add_trace(
      go.Scatter(
          x=np.arange(1, len(acc)+1), y=acc,
          mode="markers+lines",
          marker=dict(
              color=PlotCFG.train_color, size=PlotCFG.marker_size,
              line=dict(color="White", width=0.5)
          ),
          line=dict(color=PlotCFG.train_color, width=PlotCFG.line_size),
          name="Training Accuracy"
      ), row=1, col=2
  )
  fig.add_trace(
      go.Scatter(
          x=np.arange(1, len(val_acc)+1), y=val_acc,
          mode="markers+lines",
          marker=dict(
              color=PlotCFG.valid_color, size=PlotCFG.marker_size,
              line=dict(color="White", width=0.5)
          ),
          line=dict(color=PlotCFG.valid_color, width=PlotCFG.line_size),
          name="Validation Accuracy"
      ), row=1, col=2
  )

  # Update Axes
  fig.update_xaxes(title="Epochs", linecolor="Black", ticks="outside", row=1, col=1)
  fig.update_xaxes(title="Epochs", linecolor="Black", ticks="outside", row=1, col=2)
  fig.update_yaxes(title="Categorical Loss", linecolor="Black", ticks="outside", row=1, col=1)
  fig.update_yaxes(title="Accuracy", linecolor="Black", ticks="outside", row=1, col=2)


  # Update Layout
  fig.update_layout(
      title="Training Loss and Metrics", title_x=0.5,
      width=950, height=400,
      showlegend=False,
      plot_bgcolor="White",
      paper_bgcolor="White"
  )

  # Show
  fig.show(iframe_connected=True)

# %%
visualize_train_val(fine_tune_history)

# %%
visualize_train_val(train_history)

# %% [markdown]
# ### Fine-tune

# %% [markdown]
# ## **Confusion Matrix**

# %%
confusion_matrix = tf.math.confusion_matrix(
        labels=true_labels,
        predictions=predictions,
        num_classes=36)

# %%
# Create Figure
fig = go.Figure()

# Heatmap
fig.add_trace(
    go.Heatmap(
        z=confusion_matrix,
        x=CLASSES,
        y=CLASSES,
        text=confusion_matrix,
        texttemplate="<b>%{text}</b>",
        textfont={"size":8},
        colorscale=[[0, '#f4f4f4'],[1.0, '#76503d']],
        showscale = False,
        ygap = 5,
        xgap = 5,
        hovertemplate=
        '''
        Actual: %{y}<br>
        Predicted: %{x}<br>
        Total: %{text}
        ''',
        name="Confusion Matrix"
    )
)

# Update Axes
fig.update_xaxes(title="<b>Predicted Values</b>", tickfont_size=10)
fig.update_yaxes(title="<b>Actual Values</b>", tickfont_size=10)

# Update Layout
fig.update_layout(title_text='Confusion Matrix', title_x=0.5, font_size=14,
                  width=1050,
                  height=1115,
                  plot_bgcolor='white',
                  showlegend=False,
)

# Show
fig.show()

# %% [markdown]
# ## **Kiểm tra ảnh trên thực tế**

# %%
# download self test, classes
# !gdown 1cBKU4hs15XqA_Gheh9Acaxuie69nnnwy
# !gdown 12ES0wAtwtEE8LOBq4KszOsnuseVyf6A_
# !unzip /content/self_test.zip -d /content/

# %%
image_location = './self_test/self_test/A.png'
classes_file = open("classes.txt")
classes_string = classes_file.readline()
classes = classes_string.split()
classes.sort()  # The predict function sends out output in sorted order.

IMAGE_SIZE = 200

img = cv2.imread(image_location)
if img is None:
    print("Error: Image not found. Please check the file path.")
else:
    img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
    img = np.array(img) / 255.0
    plt.imshow(img)
    plt.axis('off')  # Hide axes for a cleaner look
    plt.show()
    
    # Reshape and predict
    img = img.reshape((1, IMAGE_SIZE, IMAGE_SIZE, 3))
    prediction = np.array(model.predict(img))
    predicted = classes[prediction.argmax()]

    print(predicted)
# Out:
# 1/1 [==============================] - 1s 997ms/step
# del
